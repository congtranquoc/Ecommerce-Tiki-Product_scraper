# %%
import pymongo
import mysql.connector
from pymongo import MongoClient
from bs4 import BeautifulSoup
import os
import json

class DataTransfer:
    def __init__(self):
        # Lấy thông tin kết nối từ biến môi trường
        self.user = 'root'
        self.password = os.getenv('DB_PASSWORD')
        self.host = 'localhost'
        self.database = 'tiki'
        self.mongodb_name = 'ecommerce'
        self.mongo_client = None
        # Kiểm tra xem các biến môi trường đã được thiết lập hay chưa
        if not all([self.user, self.password, self.host, self.database]):
            raise ValueError("Các biến môi trường không được thiết lập đầy đủ.")

    def mongodb_connection(self):
        # Kiểm tra kết nối tới MongoDB
        try:
            self.mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
            collection_names = self.mongo_client.list_database_names()
            if self.mongodb_name not in collection_names:
                raise ValueError(f"Collection {self.database} không tồn tại trong MongoDB.")
            database = self.mongo_client[self.mongodb_name]
            self.mongo_collection = database['products']
            print(f"Mongodb connected")
        except pymongo.errors.ConnectionFailure:
            raise ValueError("Không thể kết nối tới MongoDB.")
            
            
            
    def mysql_connection(self):
        # Kiểm tra kết nối tới MySQL
        try:
            self.mysql_cnx = mysql.connector.connect(user=self.user, password=self.password,
                                                     host=self.host)
            self.mysql_cursor = self.mysql_cnx.cursor()
        except mysql.connector.Error:
            raise ValueError("Không thể kết nối tới MySQL.")
            
    def check_create_database(self):
        # Kiểm tra xem cơ sở dữ liệu đã tồn tại hay chưa
        check_query = "SHOW DATABASES LIKE %s"
        self.mysql_cursor.execute(check_query, (self.database,))
        result = self.mysql_cursor.fetchone()
        if result:
            print(f"Cơ sở dữ liệu '{self.database}' đã tồn tại.")
        else:
            # Tạo cơ sở dữ liệu
            create_query = f"CREATE DATABASE {self.database}"
            self.mysql_cursor.execute(create_query)
            print(f"Cơ sở dữ liệu '{self.database}' đã được tạo.")
            
    def check_create_table(self, table):
        # Sử dụng cơ sở dữ liệu
        use_query = f"USE {self.database}"
        self.mysql_cursor.execute(use_query)

        # Kiểm tra xem bảng đã tồn tại hay chưa
        check_query = "SHOW TABLES LIKE %s"
        self.mysql_cursor.execute(check_query, (table,))
        result = self.mysql_cursor.fetchone()
        if result:
            print(f"Bảng '{table}' đã tồn tại.")
        else:
            create_query = """
                CREATE TABLE tiki_product_data (
                    id BIGINT PRIMARY KEY,
                    product_name LONGTEXT,
                    short_description LONGTEXT,
                    description LONGTEXT,
                    url LONGTEXT,
                    rating DECIMAL(4, 2),
                    sold_quantity BIGINT,
                    price DECIMAL(30, 2),
                    category_id VARCHAR(100),
                    day_ago_created VARCHAR(100)
                )
            """
            self.mysql_cursor.execute(create_query)
            print(f"Bảng '{table}' đã được tạo.")
            
            
    def extract_data(self, doc):
        id_product = doc.get("id", "")
        print(id_product)
        product_name = doc.get("name", "")
        short_description = doc.get("short_description", "")
        url = doc.get("short_url", "")
        description = doc.get("description", "")
        rating = doc.get("rating_average", "")
        sold_quantity = doc.get("quantity_sold")
        val = 0
        if sold_quantity:
            val = sold_quantity.get("value") or 0
        price = doc.get("price", "")
        category = doc.get("categories", {})
        category_id = 0
        if category:
            category_id = category.get("id", "")
        day_ago_created = doc.get("day_ago_created") or 0
        # Làm sạch mô tả bằng cách loại bỏ các tag HTML thừa
        soup = BeautifulSoup(description, "html.parser")
        cleaned_description = soup.get_text()

        return (id_product, product_name, short_description, url,cleaned_description, rating, val, price, category_id,day_ago_created)
    
    def insert_data_to_mysql(self, table):
        # Kiểm tra và tạo cơ sở dữ liệu (nếu chưa tồn tại)
        self.check_create_database()

        # Kiểm tra và tạo bảng (nếu chưa tồn tại)
        self.check_create_table(table)
        
        # Chèn dữ liệu vào MySQL
        insert_query = f"""
            INSERT INTO {table} (id, product_name, short_description, url, description, rating, sold_quantity, price, category_id, day_ago_created)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s, %s)
        """
#         self.mysql_cnx = mysql.connector.connect(user=self.user, password=self.password,
#                                                      host=self.host)

        # Thực hiện truy vấn aggregate
        pipeline = [
            {
                "$project": {
                    "_id": 0,
                    "id": 1,
                    "name": 1,
                    "short_description": 1,
                    "short_url": 1,
                    "description": 1,
                    "rating_average": 1,
                    "quantity_sold.value": 1,
                    "quantity_sold.price": 1,
                    "categories.id": 1,
                    "day_ago_created": 1
                }
            },
            {
                "$out": "exported_collection"
            }
        ]
        mongo_data = self.mongo_collection.aggregate(pipeline)
        list_data = []
        for doc in mongo_data:
            data = self.extract_data(doc)
            list_data.append(data)
            if len(list_data) == 3000:
                self.mysql_cursor.executemany(insert_query, list_data)
                self.mysql_cnx.commit()
                list_data = []

        # Chèn dữ liệu còn lại vào MySQL
        if len(list_data) > 0:
            self.mysql_cursor.executemany(insert_query, list_data)
            self.mysql_cnx.commit()

        # Lưu thay đổi vào cơ sở dữ liệu MySQL
        self.mysql_cnx.commit()

    def close_connection(self):
        # Đóng con trỏ và kết nối MySQL
        self.mysql_cursor.close()
        self.mysql_cnx.close()

        # Đóng kết nối MongoDB
        self.mongo_client.close()

def main():
    data_transfer = DataTransfer()
    data_transfer.mongodb_connection()
    data_transfer.mysql_connection()
    # Chèn dữ liệu vào MySQL
    data_transfer.insert_data_to_mysql('tiki_product_data')
    # Đóng kết nối
    data_transfer.close_connection()

if __name__ == "__main__":
    main()
# Out:
# Mongodb connected
# Cơ sở dữ liệu 'tiki' đã tồn tại.
# Bảng 'tiki_product_data' đã tồn tại.
# <pymongo.cursor.Cursor object at 0x000001E9DCA42E00>
# {'_id': ObjectId('649942c8e9c823ca18daca0b'), 'id': 46600215, 'sku': '6636922032221', 'name': 'Hộp kẹp tóc cho bé - Màu cam (Quà tặng đáng yêu cho bé gái) - kèm hộp có quai xách', 'url_key': 'hop-kep-toc-cho-be-mau-cam-qua-tang-dang-yeu-cho-be-gai-kem-hop-co-quai-xach-p46600215', 'url_path': 'hop-kep-toc-cho-be-mau-cam-qua-tang-dang-yeu-cho-be-gai-kem-hop-co-quai-xach-p46600215.html?spid=46600216', 'type': 'simple', 'author_name': '', 'book_cover': None, 'brand_name': 'OEM', 'short_description': '- Sản phẩm hộp kẹp tóc bao gồm: 13 loại kẹp khác nhau: kẹp tóc nơ lớn, nơ nhỏ, kẹp tóc thỏ, kẹp tóc vương miệng, kẹp hoa, kẹp tóc ngôi cột tóc, trong đó là 2 cột đôi 2 bên và 1 dây băng.- Các kẹp tóc ...', 'price': 67000, 'list_price': 67000, 'badges': [{'code': 'new_pdp', 'text': 'v1'}], 'badges_new': [], 'discount': 0, 'discount_rate': 0, 'rating_average': 4.7, 'review_count': 211, 'order_count': 0, 'favourite_count': 0, 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/9e/dc/73/ed2c0fef52f1dd71edea8173e0a607cf.jpg', 'thumbnail_width': 280, 'thumbnail_height': 280, 'freegift_items': [], 'has_ebook': False, 'inventory_status': 'available', 'is_visible': False, 'productset_id': 2035, 'productset_group_name': '', 'seller': None, 'is_flower': False, 'is_gift_card': False, 'inventory': {'product_virtual_type': None, 'fulfillment_type': 'tiki_delivery'}, 'url_attendant_input_form': '', 'option_color': [], 'stock_item': {'max_sale_qty': 1000, 'min_sale_qty': 1, 'preorder_date': None, 'qty': 1000}, 'salable_type': None, 'seller_product_id': 219178561, 'installment_info': None, 'url_review': '', 'bundle_deal': False, 'quantity_sold': {'text': 'Đã bán 1107', 'value': 1107}, 'video_url': 'https://sand.tikicdn.com/ts/video/87/85/08/bc299a2e6721fedd43916fd9eef67cd0.mp4', 'tiki_live': None, 'original_price': 67000, 'shippable': True, 'impression_info': [{'impression_id': 'thanos-product-BfRhgfzpabAf65fQ', 'metadata': {'price': 61998, 'rating_average': 0, 'reviews_count': 0, 'seller_product_id': 219178561}, 'checksum': ''}, {'impression_id': 'f774cb87-c83d-47f7-a908-daa65ec1306f', 'metadata': {'product_id': 2035, 'service_name': 'reco', 'version': 'p_category_mpid_listing_v1_202306250600'}, 'checksum': ''}], 'advertisement': None, 'availability': 1, 'primary_category_path': '1/2/2549/11603/5192/5280', 'product_reco_score': 0, 'seller_id': 37005, 'add_on': [{'id': 249387447, 'name': '[12 Tháng] Gói an tâm sử dụng sản phẩm', 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/ae/8b/82/2d87581a51f5188d98d8f1afc535dad8.png', 'price': 1000, 'add_on_description': 'Bảo hiểm cho bạn và người thân trước những sự cố bất ngờ trong quá trình sử dụng sản phẩm\nThời hạn bảo hiểm: 12 tháng\nBồi hoàn chi phí y tế: 500% giá bán sản phẩm, tối đa 15.000.000 ₫\nĐền bù thiệt hại tài sản: 500% giá bán sản phẩm, tối đa 15.000.000 ₫\nBồi thường khi tử vong, thương tật: 500% giá bán sản phẩm, tối thiểu 10.000.000 ₫ và tối đa 200.000.000 ₫\nÁp dụng cho các sản phẩm mua trên Tiki bán kèm bảo hiểm này\nGởi yêu cầu bồi thường 100% trực tuyến\nDịch vụ Bảo hiểm cung cấp bởi Công ty Bảo hiểm PVI uy tín\nBấm THÔNG TIN CHI TIẾT bên dưới để xem toàn bộ quyền lợi và nội dung chương trình', 'add_on_description_list': ['Bảo hiểm cho bạn và người thân trước những sự cố bất ngờ trong quá trình sử dụng sản phẩm', 'Thời hạn bảo hiểm: 12 tháng', 'Bồi hoàn chi phí y tế: 500% giá bán sản phẩm, tối đa 15.000.000 ₫', 'Đền bù thiệt hại tài sản: 500% giá bán sản phẩm, tối đa 15.000.000 ₫', 'Bồi thường khi tử vong, thương tật: 500% giá bán sản phẩm, tối thiểu 10.000.000 ₫ và tối đa 200.000.000 ₫', 'Áp dụng cho các sản phẩm mua trên Tiki bán kèm bảo hiểm này', 'Gởi yêu cầu bồi thường 100% trực tuyến', 'Dịch vụ Bảo hiểm cung cấp bởi Công ty Bảo hiểm PVI uy tín', 'Bấm THÔNG TIN CHI TIẾT bên dưới để xem toàn bộ quyền lợi và nội dung chương trình'], 'list_price': 1000, 'is_visible': False, 'url': 'https://tiki.vn/12-thang-goi-an-tam-su-dung-san-pham-p249387447.html',  ...
# {'_id': ObjectId('649942c8e9c823ca18daca0c'), 'id': 116198703, 'sku': '5510672647796', 'name': '50 chiếc khẩu trang em bé May 10', 'url_key': '50-chiec-khau-trang-em-be-may-10-p116198703', 'url_path': '50-chiec-khau-trang-em-be-may-10-p116198703.html?spid=116198704', 'type': 'simple', 'author_name': '', 'book_cover': None, 'brand_name': 'May 10', 'short_description': '50 chiếc khẩu trang kháng khuẩn 4 lớp hàng May 10 chính hãng\xa02 màu xanh và trắng đóng gói ngẫu nhiên\xa0\xa0...', 'price': 34000, 'list_price': 34000, 'badges': [{'code': 'new_pdp', 'text': 'v1'}], 'badges_new': [], 'discount': 0, 'discount_rate': 0, 'rating_average': 4.7, 'review_count': 70, 'order_count': 0, 'favourite_count': 0, 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/d0/e3/32/c5077e6ccd45fcd42260cf148c9d5f3b.jpg', 'thumbnail_width': 280, 'thumbnail_height': 280, 'freegift_items': [], 'has_ebook': False, 'inventory_status': 'available', 'is_visible': False, 'productset_id': 2109, 'productset_group_name': '', 'seller': None, 'is_flower': False, 'is_gift_card': False, 'inventory': {'product_virtual_type': None, 'fulfillment_type': 'dropship'}, 'url_attendant_input_form': '', 'option_color': [], 'stock_item': {'max_sale_qty': 1000, 'min_sale_qty': 1, 'preorder_date': None, 'qty': 1000}, 'salable_type': None, 'seller_product_id': 116198704, 'installment_info': None, 'url_review': '', 'bundle_deal': False, 'quantity_sold': {'text': 'Đã bán 555', 'value': 555}, 'video_url': None, 'tiki_live': None, 'original_price': 34000, 'shippable': True, 'impression_info': [{'impression_id': 'thanos-product-hHQ6kek0SsMZvC6U', 'metadata': {'price': 34000, 'rating_average': 4.7, 'reviews_count': 70, 'seller_product_id': 116198704}, 'checksum': ''}, {'impression_id': 'bcdcb0d4-10b9-4e22-936f-340dbc5dd0b0', 'metadata': {'product_id': 2109, 'service_name': 'reco', 'version': 'p_category_mpid_listing_v1_202306250600'}, 'checksum': ''}], 'advertisement': None, 'availability': 1, 'primary_category_path': '1/2/2549/11603/5192/8491', 'product_reco_score': 0, 'seller_id': 16588, 'all_time_quantity_sold': 555, 'asa_cashback_widget': {'sep': 0, 'rate': 205, 'astra_convert_rate': 0, 'text_color': '#402DA1', 'short_description': 'Tham gia các gói thành viên Astra Rewards cao cấp hơn để được nhiều ưu đãi hơn', 'background_color': '#F2F0FE', 'asa_plus_badge': '', 'new_badge': 'https://salt.tikicdn.com/ts/upload/43/01/71/d74d0e9e37a9bb14f35dcc0c816d2038.gif', 'text': 'Thưởng 0,33 ASA (≈ 68đ)', 'icon': {'height': 16, 'width': 13, 'url': 'https://salt.tikicdn.com/ts/upload/df/e2/b4/063c4d55ca380f818547f00f5175d39f.png'}, 'button': {'text': 'Khám phá thêm', 'url': 'https://tiki.vn/sep/my-sep'}, 'amplitude': {'has_freeship_plus_benefit': True, 'partner_rewards_amount': 0, 'tiki_rewards_amount': 0.33217994, 'total_rewards_amount': 0.33217994}, 'benefits': {'title': 'Bạn là thành viên', 'sub_title': 'Thưởng 0,33 ASA', 'benefit_text': 'Điểm thưởng Astra dùng để làm gì?', 'sub_icon': 'https://salt.tikicdn.com/ts/upload/7a/bf/c4/6ae829cb4698d5badb38413c0dafe354.png', 'type': 'sep_required', 'information_url': 'https://tiki.vn/sep/my-sep', 'icon_title': 'https://salt.tikicdn.com/ts/ta/1b/13/fa/0d470315888a2551f4645632a99023a3.png', 'list': [{'icon': 'https://salt.tikicdn.com/ts/upload/31/1a/54/f4ad6056005c3c4b91d746cd5cd72e5a.png', 'text': 'Đổi Astra lấy mã giảm giá & freeship', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/c9/a4/3f/ce4ec9a0e3c40aeb75a41ec4c181382f.png', 'text': 'Astra có thể trao đổi mua bán sang Tiki Xu', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/4c/26/19/fc8035082d1c3cf77e23bd2529d93f1e.png', 'text': 'Astra sinh lời khi bỏ ống Heo Vàng Astra', 'link': None}]}, 'non_login_url_path': 'https://tiki.vn/sep'}, 'benefits': [{'icon': 'https://salt.tikicdn.com/ts/upload/2c/48/44/720434869e103b03aaaf1a104d91ad25.png', 'text': 'Hoàn tiền<br><b>111%</b><br>nếu hàng giả'}, {'icon': 'https://salt.tikicdn.com/ts/upload/4b/a1/23/1606089d54 ...
# {'_id': ObjectId('649942c8e9c823ca18daca0d'), 'id': 252600656, 'sku': '8193622825407', 'name': 'Đồ bộ bé trai vải thun hiệu MIMYKID in hình 3D quần giả jean, quần áo trẻ em - LMTK-B07TH2', 'url_key': 'do-bo-be-trai-vai-thun-hieu-mimykid-in-hinh-3d-quan-gia-jean-quan-ao-tre-em-lmtk-b07th2-p252600656', 'url_path': 'do-bo-be-trai-vai-thun-hieu-mimykid-in-hinh-3d-quan-gia-jean-quan-ao-tre-em-lmtk-b07th2-p252600656.html?spid=252600658', 'type': 'configurable', 'author_name': '', 'book_cover': None, 'brand_name': 'Mimy Kid', 'short_description': 'Đồ bộ bé trai vải thun hiệu MIMYKID in hình 3D quần giả jean, quần áo trẻ em - LMTK-B07TH2\xa0\xa0THÔNG\xa0TIN\xa0SẢN\xa0PHẨM\xa0Sản phẩm: Bộ quần áo cho bé trai 3D hoạt hình năng động, cá tínhKiểu dáng: Bộ đồ ch...', 'price': 35000, 'list_price': 35000, 'badges': [{'code': 'new_pdp', 'text': 'v1'}], 'badges_new': [], 'discount': 0, 'discount_rate': 0, 'rating_average': 5, 'review_count': 9, 'order_count': 0, 'favourite_count': 0, 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/89/6f/a0/b2f439f733b5fbd725f2bfb61eb55aa9.jpg', 'thumbnail_width': 280, 'thumbnail_height': 280, 'freegift_items': [], 'has_ebook': False, 'inventory_status': 'available', 'is_visible': False, 'productset_id': 2019, 'productset_group_name': '', 'seller': None, 'is_flower': False, 'is_gift_card': False, 'inventory': {'product_virtual_type': None, 'fulfillment_type': 'dropship'}, 'url_attendant_input_form': '', 'option_color': [], 'stock_item': {'max_sale_qty': 1000, 'min_sale_qty': 1, 'preorder_date': None, 'qty': 1000}, 'salable_type': None, 'seller_product_id': 252600674, 'installment_info': None, 'url_review': '', 'bundle_deal': False, 'quantity_sold': {'text': 'Đã bán 17', 'value': 17}, 'video_url': 'https://sand.tikicdn.com/ts/video/8e/ec/00/3a69b2add3af33a1d0a5f79b95e4810f.mp4', 'tiki_live': None, 'original_price': 35000, 'shippable': True, 'impression_info': [{'impression_id': 'thanos-product-few5SnbdQHYpxvz2', 'metadata': {'price': 39000, 'rating_average': 5, 'reviews_count': 9, 'seller_product_id': 252600674}, 'checksum': ''}, {'impression_id': '242568bf-1822-43cf-ac4e-9a6114800a98', 'metadata': {'product_id': 2019, 'service_name': 'reco', 'version': 'p_category_mpid_listing_v1_202306250600'}, 'checksum': ''}], 'advertisement': None, 'availability': 1, 'primary_category_path': '1/2/2549/11603/5190/8482/5261', 'product_reco_score': 0, 'seller_id': 9311, 'all_time_quantity_sold': 17, 'asa_cashback_widget': {'sep': 0, 'rate': 205, 'astra_convert_rate': 0, 'text_color': '#402DA1', 'short_description': 'Tham gia các gói thành viên Astra Rewards cao cấp hơn để được nhiều ưu đãi hơn', 'background_color': '#F2F0FE', 'asa_plus_badge': 'https://salt.tikicdn.com/ts/upload/9e/93/48/33bcc35a1465f46346c03a17d0c36ab8.png', 'text': 'Thưởng 4,89 ASA (≈ 1.001đ)', 'icon': {'height': 16, 'width': 13, 'url': 'https://salt.tikicdn.com/ts/upload/df/e2/b4/063c4d55ca380f818547f00f5175d39f.png'}, 'button': {'text': 'Khám phá thêm', 'url': 'https://tiki.vn/sep/my-sep'}, 'amplitude': {'has_freeship_plus_benefit': True, 'partner_rewards_amount': 4, 'tiki_rewards_amount': 0.34194994, 'total_rewards_amount': 4.88740449}, 'benefits': {'title': 'Bạn là thành viên', 'sub_title': 'Thưởng 0.34194994 ASA và thêm 4.54545455 ASA với sản phẩm Astra+', 'benefit_text': 'Điểm thưởng Astra dùng để làm gì?', 'sub_icon': 'https://salt.tikicdn.com/ts/upload/7a/bf/c4/6ae829cb4698d5badb38413c0dafe354.png', 'type': 'sep_required', 'information_url': 'https://tiki.vn/sep/my-sep', 'icon_title': 'https://salt.tikicdn.com/ts/ta/1b/13/fa/0d470315888a2551f4645632a99023a3.png', 'list': [{'icon': 'https://salt.tikicdn.com/ts/upload/31/1a/54/f4ad6056005c3c4b91d746cd5cd72e5a.png', 'text': 'Đổi Astra lấy mã giảm giá & freeship', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/c9/a4/3f/ce4ec9a0e3c40aeb75a41ec4c181382f.png', 'text': 'Astra có thể trao đổi mua bán sang Tiki Xu', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/4c ...
# {'_id': ObjectId('649942c8e9c823ca18daca0e'), 'id': 164091744, 'sku': '4070437171707', 'name': 'Bộ Siêu Nhân Nhện 4 Món Áo Choàng, Mặt Nạ, Gang Tay Kèm Đĩa Spiderman Cho Bé - Hàng Loại 1 - Chính Hãng MINIIN', 'url_key': 'bo-sieu-nhan-nhen-4-mon-ao-choang-mat-na-gang-tay-kem-dia-spiderman-cho-be-hang-loai-1-chinh-hang-miniin-p164091744', 'url_path': 'bo-sieu-nhan-nhen-4-mon-ao-choang-mat-na-gang-tay-kem-dia-spiderman-cho-be-hang-loai-1-chinh-hang-miniin-p164091744.html?spid=164091745', 'type': 'simple', 'author_name': '', 'book_cover': None, 'brand_name': 'MINIIN', 'short_description': 'Bộ Siêu Nhân Nhện 4 Món Áo Choàng, Mặt Nạ, Gang Tay Kèm Đĩa Spiderman Cho Bé - Hàng Loại 1 - Chính Hãng MINIINBộ áo choàng mặt nạ găng tay kèm đĩa siêu nhân cho bé– Bộ sản phẩm gồm : Áo chàng , mặt...', 'price': 135150, 'list_price': 159000, 'badges': [{'code': 'new_pdp', 'text': 'v1'}], 'badges_new': [], 'discount': 23850, 'discount_rate': 15, 'rating_average': 4, 'review_count': 12, 'order_count': 0, 'favourite_count': 0, 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/0a/04/58/ea0f3ea14962d1990b4faf2711eaca4b.jpg', 'thumbnail_width': 280, 'thumbnail_height': 280, 'freegift_items': [], 'has_ebook': False, 'inventory_status': 'available', 'is_visible': False, 'productset_id': 2019, 'productset_group_name': '', 'seller': None, 'is_flower': False, 'is_gift_card': False, 'inventory': {'product_virtual_type': None, 'fulfillment_type': 'dropship'}, 'url_attendant_input_form': '', 'option_color': [], 'stock_item': {'max_sale_qty': 1000, 'min_sale_qty': 1, 'preorder_date': None, 'qty': 1000}, 'salable_type': None, 'seller_product_id': 164091745, 'installment_info': None, 'url_review': '', 'bundle_deal': False, 'quantity_sold': {'text': 'Đã bán 28', 'value': 28}, 'video_url': 'https://sand.tikicdn.com/ts/video/9c/10/42/3878e9bff75bd37e44558d85926c6398.mp4', 'tiki_live': None, 'original_price': 159000, 'shippable': True, 'impression_info': [{'impression_id': 'thanos-product-zUgsSVsFrTMrqf1T', 'metadata': {'price': 135150, 'rating_average': 4, 'reviews_count': 12, 'seller_product_id': 164091745}, 'checksum': ''}, {'impression_id': '9f4e604a-95a0-46c9-ac96-cec3f6f5c9e1', 'metadata': {'product_id': 2019, 'service_name': 'reco', 'version': 'p_category_mpid_listing_v1_202306250600'}, 'checksum': ''}], 'advertisement': None, 'availability': 1, 'primary_category_path': '1/2/2549/11603/5190/8482/5261', 'product_reco_score': 0, 'seller_id': 134678, 'all_time_quantity_sold': 28, 'asa_cashback_widget': {'sep': 0, 'rate': 204, 'astra_convert_rate': 0, 'text_color': '#402DA1', 'short_description': 'Tham gia các gói thành viên Astra Rewards cao cấp hơn để được nhiều ưu đãi hơn', 'background_color': '#F2F0FE', 'asa_plus_badge': '', 'new_badge': 'https://salt.tikicdn.com/ts/upload/43/01/71/d74d0e9e37a9bb14f35dcc0c816d2038.gif', 'text': 'Thưởng 1,32 ASA (≈ 269đ)', 'icon': {'height': 16, 'width': 13, 'url': 'https://salt.tikicdn.com/ts/upload/df/e2/b4/063c4d55ca380f818547f00f5175d39f.png'}, 'button': {'text': 'Khám phá thêm', 'url': 'https://tiki.vn/sep/my-sep'}, 'amplitude': {'has_freeship_plus_benefit': True, 'partner_rewards_amount': 0, 'tiki_rewards_amount': 1.32041526, 'total_rewards_amount': 1.32041526}, 'benefits': {'title': 'Bạn là thành viên', 'sub_title': 'Thưởng 1,32 ASA', 'benefit_text': 'Điểm thưởng Astra dùng để làm gì?', 'sub_icon': 'https://salt.tikicdn.com/ts/upload/7a/bf/c4/6ae829cb4698d5badb38413c0dafe354.png', 'type': 'sep_required', 'information_url': 'https://tiki.vn/sep/my-sep', 'icon_title': 'https://salt.tikicdn.com/ts/ta/1b/13/fa/0d470315888a2551f4645632a99023a3.png', 'list': [{'icon': 'https://salt.tikicdn.com/ts/upload/31/1a/54/f4ad6056005c3c4b91d746cd5cd72e5a.png', 'text': 'Đổi Astra lấy mã giảm giá & freeship', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/c9/a4/3f/ce4ec9a0e3c40aeb75a41ec4c181382f.png', 'text': 'Astra có thể trao đổi mua bán sang Tiki Xu', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts ...
# {'_id': ObjectId('649942c8e9c823ca18daca0f'), 'id': 20497918, 'sku': '3835184749004', 'name': 'Phao Bơi Cho Bé - Phao Bơi Hình Thú Ngộ Nghĩnh', 'url_key': 'phao-boi-cho-be-phao-boi-hinh-thu-ngo-nghinh-p20497918', 'url_path': 'phao-boi-cho-be-phao-boi-hinh-thu-ngo-nghinh-p20497918.html?spid=50822612', 'type': 'simple', 'author_name': '', 'book_cover': None, 'brand_name': 'OEM', 'short_description': 'Phao bơi hình thú ngộ nghĩnh cho bé được ví như bộ sưu tập các con thú trên bể bơi như hổ, vịt, voi, rắn… sẽ giúp bé trở nên nổi bật trên bể bơi đồng thời đảm bảo an toàn cho bé cũng như giúp bé hoàn ...', 'price': 48000, 'list_price': 80000, 'badges': [{'code': 'new_pdp', 'text': 'v1'}], 'badges_new': [], 'discount': 32000, 'discount_rate': 40, 'rating_average': 4.6, 'review_count': 31, 'order_count': 0, 'favourite_count': 0, 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/92/97/c3/cbe73fac4a622cccbc81df11e44a0abd.jpeg', 'thumbnail_width': 280, 'thumbnail_height': 280, 'freegift_items': [], 'has_ebook': False, 'inventory_status': 'available', 'is_visible': False, 'productset_id': 2043, 'productset_group_name': '', 'seller': None, 'is_flower': False, 'is_gift_card': False, 'inventory': {'product_virtual_type': None, 'fulfillment_type': 'dropship'}, 'url_attendant_input_form': '', 'option_color': [], 'stock_item': {'max_sale_qty': 1000, 'min_sale_qty': 1, 'preorder_date': None, 'qty': 1000}, 'salable_type': None, 'seller_product_id': 50822612, 'installment_info': None, 'url_review': '', 'bundle_deal': False, 'quantity_sold': {'text': 'Đã bán 141', 'value': 141}, 'video_url': None, 'tiki_live': None, 'original_price': 80000, 'shippable': True, 'impression_info': [{'impression_id': 'thanos-product-AbWm2z2M0iMO6CID', 'metadata': {'price': 48000, 'rating_average': 4.6, 'reviews_count': 31, 'seller_product_id': 50822612}, 'checksum': ''}, {'impression_id': 'b901bdb3-c279-4d64-b1fd-9273be48e584', 'metadata': {'product_id': 2043, 'service_name': 'reco', 'version': 'p_category_mpid_listing_v1_202306250600'}, 'checksum': ''}], 'advertisement': None, 'availability': 1, 'primary_category_path': '1/2/2549/11603/5192/5616', 'product_reco_score': 0, 'seller_id': 77027, 'all_time_quantity_sold': 141, 'asa_cashback_widget': {'sep': 0, 'rate': 205, 'astra_convert_rate': 0, 'text_color': '#402DA1', 'short_description': 'Tham gia các gói thành viên Astra Rewards cao cấp hơn để được nhiều ưu đãi hơn', 'background_color': '#F2F0FE', 'asa_plus_badge': 'https://salt.tikicdn.com/ts/upload/9e/93/48/33bcc35a1465f46346c03a17d0c36ab8.png', 'text': 'Thưởng 6,70 ASA (≈ 1.373đ)', 'icon': {'height': 16, 'width': 13, 'url': 'https://salt.tikicdn.com/ts/upload/df/e2/b4/063c4d55ca380f818547f00f5175d39f.png'}, 'button': {'text': 'Khám phá thêm', 'url': 'https://tiki.vn/sep/my-sep'}, 'amplitude': {'has_freeship_plus_benefit': True, 'partner_rewards_amount': 6, 'tiki_rewards_amount': 0.46829268, 'total_rewards_amount': 6.70205891}, 'benefits': {'title': 'Bạn là thành viên', 'sub_title': 'Thưởng 0.46829268 ASA và thêm 6.23376623 ASA với sản phẩm Astra+', 'benefit_text': 'Điểm thưởng Astra dùng để làm gì?', 'sub_icon': 'https://salt.tikicdn.com/ts/upload/7a/bf/c4/6ae829cb4698d5badb38413c0dafe354.png', 'type': 'sep_required', 'information_url': 'https://tiki.vn/sep/my-sep', 'icon_title': 'https://salt.tikicdn.com/ts/ta/1b/13/fa/0d470315888a2551f4645632a99023a3.png', 'list': [{'icon': 'https://salt.tikicdn.com/ts/upload/31/1a/54/f4ad6056005c3c4b91d746cd5cd72e5a.png', 'text': 'Đổi Astra lấy mã giảm giá & freeship', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/c9/a4/3f/ce4ec9a0e3c40aeb75a41ec4c181382f.png', 'text': 'Astra có thể trao đổi mua bán sang Tiki Xu', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/4c/26/19/fc8035082d1c3cf77e23bd2529d93f1e.png', 'text': 'Astra sinh lời khi bỏ ống Heo Vàng Astra', 'link': None}]}, 'non_login_url_path': 'https://tiki.vn/sep'}, 'benefits': [{'icon': 'https://salt.tikicdn.com/ts/upload/2c/48/ ...
# {'_id': ObjectId('649942c8e9c823ca18daca10'), 'id': 98023002, 'sku': '3830784263820', 'name': 'Set kẹp tóc bé gái ngộ nghĩnh nhiều hình 14 chi tiết PKT0012B', 'url_key': 'set-kep-toc-be-gai-ngo-nghinh-nhieu-hinh-14-chi-tiet-pkt0012b-p98023002', 'url_path': 'set-kep-toc-be-gai-ngo-nghinh-nhieu-hinh-14-chi-tiet-pkt0012b-p98023002.html?spid=263202854', 'type': 'configurable', 'author_name': '', 'book_cover': None, 'brand_name': 'OEM', 'short_description': '       SET KẸP TÓC BÉ GÁI 14 CHI TIẾT NHIỀU HÌNH NHIỀU MÀU   * ̀ ̆́: 7 màu.   * ̂́ ̣̂: nhiều chất liệu tổng hợp.   -    đ̂̉ đ̛̛̣ ̛ ̂́  ́ .   +   :  ́ ̣ - Đ̂́ Đ - ̀ ̣̂   + :    + :    * ̀ ́ ...', 'price': 22000, 'list_price': 22000, 'badges': [{'code': 'new_pdp', 'text': 'v1'}], 'badges_new': [], 'discount': 0, 'discount_rate': 0, 'rating_average': 0, 'review_count': 0, 'order_count': 0, 'favourite_count': 0, 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/bb/93/b8/9506fd28ab0b776927c2898feac2cdf9.jpg', 'thumbnail_width': 280, 'thumbnail_height': 280, 'freegift_items': [], 'has_ebook': False, 'inventory_status': 'available', 'is_visible': False, 'productset_id': 2035, 'productset_group_name': '', 'seller': None, 'is_flower': False, 'is_gift_card': False, 'inventory': {'product_virtual_type': None, 'fulfillment_type': 'dropship'}, 'url_attendant_input_form': '', 'option_color': [], 'stock_item': {'max_sale_qty': 1000, 'min_sale_qty': 1, 'preorder_date': None, 'qty': 1000}, 'salable_type': None, 'seller_product_id': 263202853, 'installment_info': None, 'url_review': '', 'bundle_deal': False, 'quantity_sold': None, 'video_url': None, 'tiki_live': None, 'original_price': 22000, 'shippable': True, 'impression_info': [{'impression_id': 'thanos-product-QbvUSLMUsWbJSa9y', 'metadata': {'price': 22000, 'rating_average': 0, 'reviews_count': 0, 'seller_product_id': 263202853}, 'checksum': ''}, {'impression_id': 'f706b4d9-ad61-48e0-9741-0709b6f4e7ac', 'metadata': {'product_id': 2035, 'service_name': 'reco', 'version': 'p_category_mpid_listing_v1_202306250600'}, 'checksum': ''}], 'advertisement': None, 'availability': 1, 'primary_category_path': '1/2/2549/11603/5192/5280', 'product_reco_score': 0, 'seller_id': 266755, 'asa_cashback_widget': {'sep': 0, 'rate': 205, 'astra_convert_rate': 0, 'text_color': '#402DA1', 'short_description': 'Tham gia các gói thành viên Astra Rewards cao cấp hơn để được nhiều ưu đãi hơn', 'background_color': '#F2F0FE', 'asa_plus_badge': '', 'new_badge': 'https://salt.tikicdn.com/ts/upload/43/01/71/d74d0e9e37a9bb14f35dcc0c816d2038.gif', 'text': 'Thưởng 0,21 ASA (≈ 44đ)', 'icon': {'height': 16, 'width': 13, 'url': 'https://salt.tikicdn.com/ts/upload/df/e2/b4/063c4d55ca380f818547f00f5175d39f.png'}, 'button': {'text': 'Khám phá thêm', 'url': 'https://tiki.vn/sep/my-sep'}, 'amplitude': {'has_freeship_plus_benefit': True, 'partner_rewards_amount': 0, 'tiki_rewards_amount': 0.21493996, 'total_rewards_amount': 0.21493996}, 'benefits': {'title': 'Bạn là thành viên', 'sub_title': 'Thưởng 0,21 ASA', 'benefit_text': 'Điểm thưởng Astra dùng để làm gì?', 'sub_icon': 'https://salt.tikicdn.com/ts/upload/7a/bf/c4/6ae829cb4698d5badb38413c0dafe354.png', 'type': 'sep_required', 'information_url': 'https://tiki.vn/sep/my-sep', 'icon_title': 'https://salt.tikicdn.com/ts/ta/1b/13/fa/0d470315888a2551f4645632a99023a3.png', 'list': [{'icon': 'https://salt.tikicdn.com/ts/upload/31/1a/54/f4ad6056005c3c4b91d746cd5cd72e5a.png', 'text': 'Đổi Astra lấy mã giảm giá & freeship', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/c9/a4/3f/ce4ec9a0e3c40aeb75a41ec4c181382f.png', 'text': 'Astra có thể trao đổi mua bán sang Tiki Xu', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/4c/26/19/fc8035082d1c3cf77e23bd2529d93f1e.png', 'text': 'Astra sinh lời khi bỏ ống Heo Vàng Astra', 'link': None}]}, 'non_login_url_path': 'https://tiki.vn/sep'}, 'benefits': [{'icon': 'https://salt.tikicdn.com/ts/upload/2c/48/44/720434869e103b03aaaf1a104d91ad25.png', 'text': 'Hoàn tiền<b ...
# {'_id': ObjectId('649942c8e9c823ca18daca11'), 'id': 75357776, 'sku': '4432910683060', 'name': 'Hộp quà cặp tóc dây buộc tóc công chúa bé gái nhiêu màu cực xinh', 'url_key': 'hop-qua-cap-toc-day-buoc-toc-cong-chua-be-gai-nhieu-mau-cuc-xinh-p75357776', 'url_path': 'hop-qua-cap-toc-day-buoc-toc-cong-chua-be-gai-nhieu-mau-cuc-xinh-p75357776.html?spid=176157103', 'type': 'configurable', 'author_name': '', 'book_cover': None, 'brand_name': 'OEM', 'short_description': 'Các mẹ ơi, các công chúa đã sắm cho mình những món đồ phụ kiện tóc thật xinh chưa ạ ^^ Các mẹ hãy tham khảo mẫu cặp tóc và dậy buộc tóc vừa xinh lại vưa tiện lợi này nhé. Đảm bảo các bé nhận được sẽ t...', 'price': 75000, 'list_price': 75000, 'badges': [{'code': 'new_pdp', 'text': 'v1'}], 'badges_new': [], 'discount': 0, 'discount_rate': 0, 'rating_average': 5, 'review_count': 30, 'order_count': 0, 'favourite_count': 0, 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/3a/d4/f5/8bb5fba7b913016b0f2d2c6dfbdbc476.jpg', 'thumbnail_width': 280, 'thumbnail_height': 280, 'freegift_items': [], 'has_ebook': False, 'inventory_status': 'available', 'is_visible': False, 'productset_id': 2035, 'productset_group_name': '', 'seller': None, 'is_flower': False, 'is_gift_card': False, 'inventory': {'product_virtual_type': None, 'fulfillment_type': 'tiki_delivery'}, 'url_attendant_input_form': '', 'option_color': [], 'stock_item': {'max_sale_qty': 1000, 'min_sale_qty': 1, 'preorder_date': None, 'qty': 1000}, 'salable_type': None, 'seller_product_id': 82700624, 'installment_info': None, 'url_review': '', 'bundle_deal': False, 'quantity_sold': {'text': 'Đã bán 170', 'value': 170}, 'video_url': None, 'tiki_live': None, 'original_price': 75000, 'shippable': True, 'impression_info': [{'impression_id': 'thanos-product-TBZPzIOwJAMwsuiQ', 'metadata': {'price': 75000, 'rating_average': 5, 'reviews_count': 30, 'seller_product_id': 82700624}, 'checksum': ''}, {'impression_id': 'f4bbdc84-6657-4f4f-8eef-e86235e360b0', 'metadata': {'product_id': 2035, 'service_name': 'reco', 'version': 'p_category_mpid_listing_v1_202306250600'}, 'checksum': ''}], 'advertisement': None, 'availability': 1, 'primary_category_path': '1/2/2549/11603/5192/5280', 'product_reco_score': 0, 'seller_id': 108828, 'add_on': [{'id': 249387447, 'name': '[12 Tháng] Gói an tâm sử dụng sản phẩm', 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/ae/8b/82/2d87581a51f5188d98d8f1afc535dad8.png', 'price': 1000, 'add_on_description': 'Bảo hiểm cho bạn và người thân trước những sự cố bất ngờ trong quá trình sử dụng sản phẩm\nThời hạn bảo hiểm: 12 tháng\nBồi hoàn chi phí y tế: 500% giá bán sản phẩm, tối đa 15.000.000 ₫\nĐền bù thiệt hại tài sản: 500% giá bán sản phẩm, tối đa 15.000.000 ₫\nBồi thường khi tử vong, thương tật: 500% giá bán sản phẩm, tối thiểu 10.000.000 ₫ và tối đa 200.000.000 ₫\nÁp dụng cho các sản phẩm mua trên Tiki bán kèm bảo hiểm này\nGởi yêu cầu bồi thường 100% trực tuyến\nDịch vụ Bảo hiểm cung cấp bởi Công ty Bảo hiểm PVI uy tín\nBấm THÔNG TIN CHI TIẾT bên dưới để xem toàn bộ quyền lợi và nội dung chương trình', 'add_on_description_list': ['Bảo hiểm cho bạn và người thân trước những sự cố bất ngờ trong quá trình sử dụng sản phẩm', 'Thời hạn bảo hiểm: 12 tháng', 'Bồi hoàn chi phí y tế: 500% giá bán sản phẩm, tối đa 15.000.000 ₫', 'Đền bù thiệt hại tài sản: 500% giá bán sản phẩm, tối đa 15.000.000 ₫', 'Bồi thường khi tử vong, thương tật: 500% giá bán sản phẩm, tối thiểu 10.000.000 ₫ và tối đa 200.000.000 ₫', 'Áp dụng cho các sản phẩm mua trên Tiki bán kèm bảo hiểm này', 'Gởi yêu cầu bồi thường 100% trực tuyến', 'Dịch vụ Bảo hiểm cung cấp bởi Công ty Bảo hiểm PVI uy tín', 'Bấm THÔNG TIN CHI TIẾT bên dưới để xem toàn bộ quyền lợi và nội dung chương trình'], 'list_price': 1000, 'is_visible': False, 'url': 'https://tiki.vn/12-thang-goi-an-tam-su-dung-san-pham-p249387447.html', 'add_on_information_title': 'Thông tin chi tiết', 'add_on_information_url': 'https://tiki.vn/bao-hiem-so/186/thong-ti ...
# {'_id': ObjectId('649942c8e9c823ca18daca12'), 'id': 252403258, 'sku': '1537961057645', 'name': 'Đồ bộ bé gái in hình 3D quần lửng vải thun hiệu MIMYKID, quần áo trẻ em - LMTK-B06GH5', 'url_key': 'do-bo-be-gai-in-hinh-3d-quan-lung-vai-thun-hieu-mimykid-quan-ao-tre-em-lmtk-b06gh5-p252403258', 'url_path': 'do-bo-be-gai-in-hinh-3d-quan-lung-vai-thun-hieu-mimykid-quan-ao-tre-em-lmtk-b06gh5-p252403258.html?spid=252403272', 'type': 'configurable', 'author_name': '', 'book_cover': None, 'brand_name': 'Mimy Kid', 'short_description': 'Đồ bộ bé gái in hình 3D quần lửng vải thun hiệu MIMYKID, quần áo trẻ em - LMTK-B06GH5\xa0THÔNG\xa0TIN\xa0SẢN\xa0PHẨM\xa0Sản\xa0phẩm:\xa0Bộ\xa0quần\xa0áo\xa0cho\xa0bé\xa0gái\xa03D\xa0hoạt\xa0hình\xa0xinh\xa0xắn\xa0đáng\xa0yêuKiểu\xa0dáng:\xa0Bộ\xa0đồ\xa0cho\xa0bé\xa0gái\xa0...', 'price': 39000, 'list_price': 56000, 'badges': [{'code': 'new_pdp', 'text': 'v1'}], 'badges_new': [], 'discount': 17000, 'discount_rate': 30, 'rating_average': 5, 'review_count': 9, 'order_count': 0, 'favourite_count': 0, 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/b5/21/64/8ef6cb41f558e0ac21db90e499644efe.jpg', 'thumbnail_width': 280, 'thumbnail_height': 280, 'freegift_items': [], 'has_ebook': False, 'inventory_status': 'available', 'is_visible': False, 'productset_id': 2017, 'productset_group_name': '', 'seller': None, 'is_flower': False, 'is_gift_card': False, 'inventory': {'product_virtual_type': None, 'fulfillment_type': 'dropship'}, 'url_attendant_input_form': '', 'option_color': [], 'stock_item': {'max_sale_qty': 1000, 'min_sale_qty': 1, 'preorder_date': None, 'qty': 1000}, 'salable_type': None, 'seller_product_id': 252403300, 'installment_info': None, 'url_review': '', 'bundle_deal': False, 'quantity_sold': {'text': 'Đã bán 14', 'value': 14}, 'video_url': 'https://sand.tikicdn.com/ts/video/8e/ec/00/a3d7a210f6236d98676b616b234020bf.mp4', 'tiki_live': None, 'original_price': 56000, 'shippable': True, 'impression_info': [{'impression_id': 'thanos-product-RJGfuhNBvAq0tWC4', 'metadata': {'price': 39000, 'rating_average': 5, 'reviews_count': 9, 'seller_product_id': 252403300}, 'checksum': ''}, {'impression_id': 'f42cc29f-35d1-4b35-ae0f-e2042703a7f0', 'metadata': {'product_id': 2017, 'service_name': 'reco', 'version': 'p_category_mpid_listing_v1_202306250600'}, 'checksum': ''}], 'advertisement': None, 'availability': 1, 'primary_category_path': '1/2/2549/11603/5189/5260', 'product_reco_score': 0, 'seller_id': 9311, 'all_time_quantity_sold': 14, 'asa_cashback_widget': {'sep': 0, 'rate': 204, 'astra_convert_rate': 0, 'text_color': '#402DA1', 'short_description': 'Tham gia các gói thành viên Astra Rewards cao cấp hơn để được nhiều ưu đãi hơn', 'background_color': '#F2F0FE', 'asa_plus_badge': 'https://salt.tikicdn.com/ts/upload/9e/93/48/33bcc35a1465f46346c03a17d0c36ab8.png', 'text': 'Thưởng 5,45 ASA (≈ 1.110đ)', 'icon': {'height': 16, 'width': 13, 'url': 'https://salt.tikicdn.com/ts/upload/df/e2/b4/063c4d55ca380f818547f00f5175d39f.png'}, 'button': {'text': 'Khám phá thêm', 'url': 'https://tiki.vn/sep/my-sep'}, 'amplitude': {'has_freeship_plus_benefit': True, 'partner_rewards_amount': 5, 'tiki_rewards_amount': 0.38102993, 'total_rewards_amount': 5.44596499}, 'benefits': {'title': 'Bạn là thành viên', 'sub_title': 'Thưởng 0.38102993 ASA và thêm 5.06493506 ASA với sản phẩm Astra+', 'benefit_text': 'Điểm thưởng Astra dùng để làm gì?', 'sub_icon': 'https://salt.tikicdn.com/ts/upload/7a/bf/c4/6ae829cb4698d5badb38413c0dafe354.png', 'type': 'sep_required', 'information_url': 'https://tiki.vn/sep/my-sep', 'icon_title': 'https://salt.tikicdn.com/ts/ta/1b/13/fa/0d470315888a2551f4645632a99023a3.png', 'list': [{'icon': 'https://salt.tikicdn.com/ts/upload/31/1a/54/f4ad6056005c3c4b91d746cd5cd72e5a.png', 'text': 'Đổi Astra lấy mã giảm giá & freeship', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/c9/a4/3f/ce4ec9a0e3c40aeb75a41ec4c181382f.png', 'text': 'Astra có thể trao đổi mua bán sang Tiki Xu', 'link': None}, { ...
# {'_id': ObjectId('649942c8e9c823ca18daca13'), 'id': 252184387, 'sku': '3752592605456', 'name': 'Đồ bộ bé gái vải thun hiệu MIMYKID in hình 3D quần lửng, quần áo trẻ em - LMTK-B06GH2', 'url_key': 'do-bo-be-gai-vai-thun-hieu-mimykid-in-hinh-3d-quan-lung-quan-ao-tre-em-lmtk-b06gh2-p252184387', 'url_path': 'do-bo-be-gai-vai-thun-hieu-mimykid-in-hinh-3d-quan-lung-quan-ao-tre-em-lmtk-b06gh2-p252184387.html?spid=252184437', 'type': 'configurable', 'author_name': '', 'book_cover': None, 'brand_name': 'Mimy Kid', 'short_description': 'Đồ bộ bé gái vải thun hiệu MIMYKID in hình 3D quần lửng, quần áo trẻ em - LMTK-B06GH2\xa0THÔNG\xa0TIN\xa0SẢN\xa0PHẨM\xa0Sản\xa0phẩm:\xa0Bộ\xa0quần\xa0áo\xa0cho\xa0bé\xa0gái\xa03D\xa0hoạt\xa0hình\xa0xinh\xa0xắn\xa0đáng\xa0yêuKiểu\xa0dáng:\xa0Bộ\xa0đồ\xa0cho\xa0bé\xa0gái\xa0...', 'price': 39000, 'list_price': 56000, 'badges': [{'code': 'new_pdp', 'text': 'v1'}], 'badges_new': [], 'discount': 17000, 'discount_rate': 30, 'rating_average': 5, 'review_count': 8, 'order_count': 0, 'favourite_count': 0, 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/15/a2/6e/1a0472995ef3e29f58036b7238755419.jpg', 'thumbnail_width': 280, 'thumbnail_height': 280, 'freegift_items': [], 'has_ebook': False, 'inventory_status': 'available', 'is_visible': False, 'productset_id': 2017, 'productset_group_name': '', 'seller': None, 'is_flower': False, 'is_gift_card': False, 'inventory': {'product_virtual_type': None, 'fulfillment_type': 'dropship'}, 'url_attendant_input_form': '', 'option_color': [], 'stock_item': {'max_sale_qty': 1000, 'min_sale_qty': 1, 'preorder_date': None, 'qty': 1000}, 'salable_type': None, 'seller_product_id': 252184419, 'installment_info': None, 'url_review': '', 'bundle_deal': False, 'quantity_sold': {'text': 'Đã bán 9', 'value': 9}, 'video_url': 'https://sand.tikicdn.com/ts/video/8e/ec/00/d611170592a9f88bed2aa263047eae5b.mp4', 'tiki_live': None, 'original_price': 56000, 'shippable': True, 'impression_info': [{'impression_id': 'thanos-product-12k6XqinwizC7rH5', 'metadata': {'price': 39000, 'rating_average': 5, 'reviews_count': 8, 'seller_product_id': 252184419}, 'checksum': ''}, {'impression_id': 'bc9e5576-577e-442d-aef4-460abee7d6f3', 'metadata': {'product_id': 2017, 'service_name': 'reco', 'version': 'p_category_mpid_listing_v1_202306250600'}, 'checksum': ''}], 'advertisement': None, 'availability': 1, 'primary_category_path': '1/2/2549/11603/5189/5260', 'product_reco_score': 0, 'seller_id': 9311, 'all_time_quantity_sold': 9, 'asa_cashback_widget': {'sep': 0, 'rate': 205, 'astra_convert_rate': 0, 'text_color': '#402DA1', 'short_description': 'Tham gia các gói thành viên Astra Rewards cao cấp hơn để được nhiều ưu đãi hơn', 'background_color': '#F2F0FE', 'asa_plus_badge': 'https://salt.tikicdn.com/ts/upload/9e/93/48/33bcc35a1465f46346c03a17d0c36ab8.png', 'text': 'Thưởng 5,45 ASA (≈ 1.116đ)', 'icon': {'height': 16, 'width': 13, 'url': 'https://salt.tikicdn.com/ts/upload/df/e2/b4/063c4d55ca380f818547f00f5175d39f.png'}, 'button': {'text': 'Khám phá thêm', 'url': 'https://tiki.vn/sep/my-sep'}, 'amplitude': {'has_freeship_plus_benefit': True, 'partner_rewards_amount': 5, 'tiki_rewards_amount': 0.38102993, 'total_rewards_amount': 5.44596499}, 'benefits': {'title': 'Bạn là thành viên', 'sub_title': 'Thưởng 0.38102993 ASA và thêm 5.06493506 ASA với sản phẩm Astra+', 'benefit_text': 'Điểm thưởng Astra dùng để làm gì?', 'sub_icon': 'https://salt.tikicdn.com/ts/upload/7a/bf/c4/6ae829cb4698d5badb38413c0dafe354.png', 'type': 'sep_required', 'information_url': 'https://tiki.vn/sep/my-sep', 'icon_title': 'https://salt.tikicdn.com/ts/ta/1b/13/fa/0d470315888a2551f4645632a99023a3.png', 'list': [{'icon': 'https://salt.tikicdn.com/ts/upload/31/1a/54/f4ad6056005c3c4b91d746cd5cd72e5a.png', 'text': 'Đổi Astra lấy mã giảm giá & freeship', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/c9/a4/3f/ce4ec9a0e3c40aeb75a41ec4c181382f.png', 'text': 'Astra có thể trao đổi mua bán sang Tiki Xu', 'link': None}, {'ic ...
# {'_id': ObjectId('649942c8e9c823ca18daca14'), 'id': 107795310, 'sku': '9984422239137', 'name': '(sẵn )balo kéo học sinh lớp 1-6 kèm túi học thêm và hộp bút video shop ', 'url_key': 'san-balo-keo-hoc-sinh-lop-1-6-kem-tui-hoc-them-va-hop-but-video-shop-p107795310', 'url_path': 'san-balo-keo-hoc-sinh-lop-1-6-kem-tui-hoc-them-va-hop-but-video-shop-p107795310.html?spid=107795320', 'type': 'configurable', 'author_name': '', 'book_cover': None, 'brand_name': 'OEM', 'short_description': '       balo to rộng thoải mái đựng đồ ạ   ba mẹ hoàn toàn yên tâm khi hàng ngày bé phải đeo rất nhiều sách đến trường   vải balo bền đẹp   cần kéo chắc chắc chắn   bánh xe kéo nhẹ-êm   tặng k...', 'price': 385000, 'list_price': 385000, 'badges': [{'code': 'new_pdp', 'text': 'v1'}], 'badges_new': [], 'discount': 0, 'discount_rate': 0, 'rating_average': 4.3, 'review_count': 21, 'order_count': 0, 'favourite_count': 0, 'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/40/b1/e0/c108e80fdc145e70604cb740a8dbfba8.jpg', 'thumbnail_width': 280, 'thumbnail_height': 280, 'freegift_items': [], 'has_ebook': False, 'inventory_status': 'available', 'is_visible': False, 'productset_id': 1993, 'productset_group_name': '', 'seller': None, 'is_flower': False, 'is_gift_card': False, 'inventory': {'product_virtual_type': None, 'fulfillment_type': 'dropship'}, 'url_attendant_input_form': '', 'option_color': [], 'stock_item': {'max_sale_qty': 1000, 'min_sale_qty': 1, 'preorder_date': None, 'qty': 1000}, 'salable_type': None, 'seller_product_id': 107795312, 'installment_info': None, 'url_review': '', 'bundle_deal': False, 'quantity_sold': {'text': 'Đã bán 65', 'value': 65}, 'video_url': None, 'tiki_live': None, 'original_price': 385000, 'shippable': True, 'impression_info': [{'impression_id': 'thanos-product-DaU5OxXR4NZeFjR7', 'metadata': {'price': 385000, 'rating_average': 4.3, 'reviews_count': 21, 'seller_product_id': 107795312}, 'checksum': ''}, {'impression_id': 'b57b7db5-6e02-4131-b53c-9b5c5b5ee5d0', 'metadata': {'product_id': 1993, 'service_name': 'reco', 'version': 'p_category_mpid_listing_v1_202306250600'}, 'checksum': ''}], 'advertisement': None, 'availability': 1, 'primary_category_path': '1/2/2549/11603/5192/4606/4608', 'product_reco_score': 0, 'seller_id': 175392, 'all_time_quantity_sold': 65, 'asa_cashback_widget': {'sep': 0, 'rate': 204, 'astra_convert_rate': 0, 'text_color': '#402DA1', 'short_description': 'Tham gia các gói thành viên Astra Rewards cao cấp hơn để được nhiều ưu đãi hơn', 'background_color': '#F2F0FE', 'asa_plus_badge': '', 'new_badge': 'https://salt.tikicdn.com/ts/upload/43/01/71/d74d0e9e37a9bb14f35dcc0c816d2038.gif', 'text': 'Thưởng 3,76 ASA (≈ 766đ)', 'icon': {'height': 16, 'width': 13, 'url': 'https://salt.tikicdn.com/ts/upload/df/e2/b4/063c4d55ca380f818547f00f5175d39f.png'}, 'button': {'text': 'Khám phá thêm', 'url': 'https://tiki.vn/sep/my-sep'}, 'amplitude': {'has_freeship_plus_benefit': True, 'partner_rewards_amount': 0, 'tiki_rewards_amount': 3.75838926, 'total_rewards_amount': 3.75838926}, 'benefits': {'title': 'Bạn là thành viên', 'sub_title': 'Thưởng 3,76 ASA', 'benefit_text': 'Điểm thưởng Astra dùng để làm gì?', 'sub_icon': 'https://salt.tikicdn.com/ts/upload/7a/bf/c4/6ae829cb4698d5badb38413c0dafe354.png', 'type': 'sep_required', 'information_url': 'https://tiki.vn/sep/my-sep', 'icon_title': 'https://salt.tikicdn.com/ts/ta/1b/13/fa/0d470315888a2551f4645632a99023a3.png', 'list': [{'icon': 'https://salt.tikicdn.com/ts/upload/31/1a/54/f4ad6056005c3c4b91d746cd5cd72e5a.png', 'text': 'Đổi Astra lấy mã giảm giá & freeship', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/c9/a4/3f/ce4ec9a0e3c40aeb75a41ec4c181382f.png', 'text': 'Astra có thể trao đổi mua bán sang Tiki Xu', 'link': None}, {'icon': 'https://salt.tikicdn.com/ts/upload/4c/26/19/fc8035082d1c3cf77e23bd2529d93f1e.png', 'text': 'Astra sinh lời khi bỏ ống Heo Vàng Astra', 'link': None}]}, 'non_login_url_path': 'https://tiki.vn/sep'}, 'benefits': [{'icon': ...
